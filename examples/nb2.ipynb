# %%
import numpy as np

# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# Here is some example text... With a slightly different plot below.

# %%
x = np.linspace(-2, 2, 100)
plt.plot(x, x**3);
